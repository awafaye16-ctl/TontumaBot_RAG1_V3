# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json("references.json")
df
# Out:
#     id                                        question_wo  \
# 0    1  Naka la mën a jëme ci ospitaal bi ngir gis dok...
# 1    2  Lan laa war a def bu ma bëggee def rendez-vous...
# 2    3            Naka laa mën a gis service urgences bi?
# 3    4  Ana ban service laa war a dem bu ma amee feeba...
# 4    5  Lan mooy ay procédure ngir def examen ci ospit...
# 5    6  Naka laa mën a jëfandikoo assurance maladie ci...
# 6    7          Ana laa war a dem ngir def prise de sang?
# 7    8           Naka laa mën a gis service pédiatrie bi?
# 8    9  Bu ma bëggee gis gynécologue, ana service laa ...
# 9   10  Lan laa war a indi bu ma bëggee dem ci ospitaa...
# 10  11  Naka laa mën a xam fan la service cardiologie ...
# 11  12           Ana laa war a dem ngir def radiographie?
# 12  13       Naka laa mën a jëme ci service maternité bi?
# 13  14  Lan laa war a def bu ma bëggee dugal sama bopp...
# 14  15    Naka laa mën a xam ay waxtu yu consultation yi?
# ...
